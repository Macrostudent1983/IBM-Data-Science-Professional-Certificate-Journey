# %% [markdown]
# # Week 4 Capstone | Data Description

# %% [markdown]
# ## Data Description:
# We are primarily making use of Toronto dataset we scrapped in Week 3.
# Data Link: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#
# ## Foursquare Data:
#
# For area/borough specific data in Toronoto, we will use "Foursquare" locational information. Foursquare is a location data provider with information about all manner of venues and events within an area of interest. Such information includes venue names, locations, menus and even photos. As such, the foursquare location platform will be used as the sole data source since all the stated required information can be obtained through the API.
#
# We are connecting to the Foursquare API to gather information about venues inside each and every neighborhood. The information obtained per venue include but are not limited to:
#
#     1. Neighborhood
#     2. Neighborhood Latitude
#     3. Neighborhood Longitude
#     4. Venue
#     5. Name of the venue e.g. the name of a store or restaurant
#     6. Venue Latitude
#     7. Venue Longitude
#     8. Venue Category
