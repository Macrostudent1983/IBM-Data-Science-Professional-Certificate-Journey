# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sze King CHONG**

# %% [markdown]
# Current: Aspiring Machine Learning Engineer

# %% [markdown]
# *I am interested in Data Science because I aim to solve problems in a way that is as objective as possible.*

# %% [markdown]
# ### My code below is going to print "SimpleSimple"

# %%
print("Simple" * 2)
# Out:
# SimpleSimple

# %% [markdown]
# Horizontal Rule below

# %% [markdown]
# ***

# %% [markdown]
# - Bullet point 1
# - Bullet point 2
# - Bullet point 3

# %% [markdown]
# ***

# %% [markdown]
# Click Hyperlink here please:
# [www.Google.com](http://www.google.com)

# %% [markdown]
# ***

# %% [markdown]
#     1. This is number 1
#     2. This is number 2
#     3. This is number 3
#     4. The end

# %% [markdown]
# ***
